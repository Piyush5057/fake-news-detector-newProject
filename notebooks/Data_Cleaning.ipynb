# %% [markdown]
# ### Data Loading & Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
fake_df = pd.read_csv("D:\ML_Projects\Fake_News_Project\data\Fake.csv")
true_df = pd.read_csv("D:\ML_Projects\Fake_News_Project\data\True.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:2: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\MSI PC\AppData\Local\Temp\ipykernel_2328\4149843208.py:1: SyntaxWarning: invalid escape sequence '\M'
#   fake_df = pd.read_csv("D:\ML_Projects\Fake_News_Project\data\Fake.csv")
# C:\Users\MSI PC\AppData\Local\Temp\ipykernel_2328\4149843208.py:2: SyntaxWarning: invalid escape sequence '\M'
#   true_df = pd.read_csv("D:\ML_Projects\Fake_News_Project\data\True.csv")

# %%
fake_df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
true_df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake_df.shape
# Out:
# (23481, 4)

# %%
true_df.shape
# Out:
# (21417, 4)

# %%
fake_df.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='str')

# %%
fake_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
true_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
fake_df.duplicated().sum()
# Out:
# np.int64(3)

# %%
true_df.duplicated().sum()
# Out:
# np.int64(206)

# %%
fake_df["label"] = 0
true_df["label"] = 1

# %%
df = pd.concat([fake_df, true_df], ignore_index=True)

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.head()
# Out:
#                                                title  \
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...
# 1  Trump drops Steve Bannon from National Securit...
# 2  Puerto Rico expects U.S. to lift Jones Act shi...
# 3   OOPS: Trump Just Accidentally Confirmed He Le...
# 4  Donald Trump heads for Scotland to reopen a go...
#
#                                                 text       subject  \
# 0  21st Century Wire says Ben Stein, reputable pr...       US_News
# 1  WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 2  (Reuters) - Puerto Rico Governor Ricardo Rosse...  politicsNews
# 3  On Monday, Donald Trump once again embarrassed...          News
# 4  GLASGOW, Scotland (Reuters) - Most U.S. presid...  politicsNews
#
#                   date  label
# 0    February 13, 2017      0
# 1       April 5, 2017       1
# 2  September 27, 2017       1
# 3         May 22, 2017      0
# 4       June 24, 2016       1

# %%
df.shape
# Out:
# (44898, 5)

# %%
df["label"].value_counts()
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  str
#  1   text     44898 non-null  str
#  2   subject  44898 non-null  str
#  3   date     44898 non-null  str
#  4   label    44898 non-null  int64
# dtypes: int64(1), str(4)
# memory usage: 1.7 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(209)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (44689, 5)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["content"] = df["title"] + " " + df["text"]

# %%
df[["content", "label"]].head()
# Out:
#                                              content  label
# 0  Ben Stein Calls Out 9th Circuit Court: Committ...      0
# 1  Trump drops Steve Bannon from National Securit...      1
# 2  Puerto Rico expects U.S. to lift Jones Act shi...      1
# 3   OOPS: Trump Just Accidentally Confirmed He Le...      0
# 4  Donald Trump heads for Scotland to reopen a go...      1

# %% [markdown]
# ### Text Cleaning

# %%
import re
import string

# %%
def clean_text(text):

    # Convert to lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'http\S+|www\S+', '', text)

    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
df["content"] = df["content"].apply(clean_text)

# %% [markdown]
# ### Feature Engineering

# %%
df["content_length"] = df["content"].apply(len)

# %%
df["word_count"] = df["content"].apply(lambda x: len(x.split()))

# %%
df["avg_word_length"] = df["content"].apply(
    lambda x: sum(len(word) for word in x.split()) / len(x.split())
    if len(x.split()) > 0 else 0
)

# %%
df[["content_length","word_count","avg_word_length"]].head()
# Out:
#    content_length  word_count  avg_word_length
# 0            1090         184         4.929348
# 1            4763         775         5.147097
# 2            1846         313         4.900958
# 3            1254         192         5.536458
# 4            3090         529         4.843100

# %% [markdown]
# ### EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x="label", data=df)
plt.xticks([0,1],["Fake","Real"])
plt.title("Fake vs Real News")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=df,
    x="content_length",
    hue="label",
    bins=50
)

plt.title("Distribution of Article Length")
plt.show()

# %% [markdown]
# ### word count distribution

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="label",
    y="word_count",
    data=df
)

plt.xticks([0,1],["Fake","Real"])

plt.show()

# %%
# Remove rows where content becomes empty
df = df[df["content"].str.strip() != ""]

# %%
df.to_csv("../data/cleaned_news.csv", index=False)
